# %% [markdown]
# # Data Preprocessing and InstanSeg Evaluation
#
# This notebook is dedicated to preprocessing microscopy images (brightfield and fluorescent) and their corresponding masks for the InstanSeg model.
# Raw data format inconsistencies are addressed here before model evaluation.
#
# **Note:** you can run this code with any image formats. Most examples, use `tiff` images, as they are less likely to get any errors from InstanSeg during training or testing. However, you can experiment with other data types, keeping in mind that it may sometimes cause unexpected errors.

# %% [markdown]
# **How to use this notebook?**
#
# 1. Make a copy of this notebook.
# 2. Load some images into the files space.
# 3. Always run `Section 1` to setup the environment.
# 4. Run the code cells you need, changing the paths so that they refer to your images and/or folders.
# 5. After making some changes to your image, you may want to pass it to one of the InstanSeg models in `Section 4`, and evaluate the effectiveness of a specific preprocessing technique.
# 6. Use `Section 5` for visualizing any image or mask if needed.

# %% [markdown]
# ## 1. Environment Setup & Model Initialization
# First, we install required dependencies and load core libraries. We then initialize the pre-trained `InstanSeg` models for both brightfield and fluorescence microscopy images.

# %%
# !pip install monai
# Out:
# Collecting monai
#   Downloading monai-1.5.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<3.0,>=1.24 in /usr/local/lib/python3.12/dist-packages (from monai) (2.0.2)
# Requirement already satisfied: torch>=2.4.1 in /usr/local/lib/python3.12/dist-packages (from monai) (2.11.0+cpu)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (3.29.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (2025.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.4.1->monai) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.4.1->monai) (3.0.3)
# Downloading monai-1.5.2-py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 20.9 MB/s eta 0:00:00
# Installing collected packages: monai
# Successfully installed monai-1.5.2

# %%
# !pip install instanseg-torch
# Out:
# Collecting instanseg-torch
#   Downloading instanseg_torch-0.1.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: einops>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from instanseg-torch) (0.8.2)
# Collecting fastremap>=1.14.0 (from instanseg-torch)
#   Downloading fastremap-1.20.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from instanseg-torch) (3.10.0)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.12/dist-packages (from instanseg-torch) (2.0.2)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from instanseg-torch) (2.32.4)
# Requirement already satisfied: scikit-image>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from instanseg-torch) (0.25.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from instanseg-torch) (2.11.0+cpu)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from instanseg-torch) (4.67.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->instanseg-torch) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->instanseg-torch) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->instanseg-torch) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->instanseg-torch) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->instanseg-torch) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->instanseg-torch) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->instanseg-torch) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->instanseg-torch) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->instanseg-torch) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->instanseg-torch) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->instanseg-torch) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->instanseg-torch) (2026.5.20)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.21.0->instanseg-torch) (1.16.3)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.21.0->instanseg-torch) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.21.0->instanseg-torch) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.21.0->instanseg-torch) (2026.4.11)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.21.0->instanseg-torch) (0.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->instanseg-torch) (3.29.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->instanseg-torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->instanseg-torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->instanseg-torch) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->instanseg-torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->instanseg-torch) (2025.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7.0->instanseg-torch) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->instanseg-torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->instanseg-torch) (3.0.3)
# Downloading instanseg_torch-0.1.1-py3-none-any.whl (126 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.1/126.1 kB 6.1 MB/s eta 0:00:00
# Downloading fastremap-1.20.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (7.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 68.0 MB/s eta 0:00:00
# Installing collected packages: fastremap, instanseg-torch
# Successfully installed fastremap-1.20.0 instanseg-torch-0.1.1

# %%
# !pip install imagecodecs
# Out:
# Collecting imagecodecs
#   Downloading imagecodecs-2026.6.6-cp312-abi3-manylinux_2_28_x86_64.whl.metadata (22 kB)
# Collecting numpy>=2.1 (from imagecodecs)
#   Downloading numpy-2.4.6-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Downloading imagecodecs-2026.6.6-cp312-abi3-manylinux_2_28_x86_64.whl (28.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.1/28.1 MB 45.4 MB/s eta 0:00:00
# Downloading numpy-2.4.6-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 48.6 MB/s eta 0:00:00
# Installing collected packages: numpy, imagecodecs
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.4.6 which is incompatible.
# Successfully installed imagecodecs-2026.6.6 numpy-2.4.6

# %%
# Deep Learning and Segmentation
import torch
import torchvision
from instanseg import InstanSeg
from instanseg.utils.utils import show_images

# Image Processing and Math
import numpy as np
import tifffile as tiff
from PIL import Image, ImageEnhance
from skimage import io
import cv2
import matplotlib.pyplot as plt

# Initialize Models
instanseg_brightfield = InstanSeg("brightfield_nuclei", verbosity=1, image_reader="skimage.io")
instanseg_fluorescence = InstanSeg("fluorescence_nuclei_and_cells", verbosity=1, image_reader="skimage.io")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_11680/3321460759.py in <cell line: 0>()
#       1 # Deep Learning and Segmentation
# ----> 2 import torch
#       3 import torchvision
#       4 from instanseg import InstanSeg
#       5 from instanseg.utils.utils import show_images
#
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py in <module>
#    2802
#    2803         del coll_meta_registrations
# -> 2804     from torch import _meta_registrations
#    2805
#    2806 # Enable CUDA Sanitizer
#
# /usr/local/lib/python3.12/dist-packages/torch/_meta_registrations.py in <module>
#      10 import torch._prims_common as utils
#      11 from torch import SymBool, SymFloat, Tensor
# ---> 12 from torch._decomp import (
#      13     _add_op_to_registry,
#      14     _convert_out_params,
#
# /usr/local/lib/python3.12/dist-packages/torch/_decomp/__init__.py in <module>
#     286 # populate the table
#     287 import torch._decomp.decompositions
# --> 288 import torch._refs
#     289
#     290
#
# /usr/local/lib/python3.12/dist-packages/torch/_refs/__init__.py in <module>
#    1497
#    1498
# -> 1499 @_make_elementwise_binary_reference(
#    1500     type_promotion_kind=ELEMENTWISE_TYPE_PROMOTION_KIND.DEFAULT,
#    1501     supports_lhs_python_scalar=False,
#
# /usr/local/lib/python3.12/dist-packages/torch/_refs/__init__.py in inner(prim)
#    1179             aten_op = utils.get_aten_op(prim, name)
#    1180         if aten_op is not None and should_register_decomposition:
# -> 1181             register_decomposition(aten_op)(_ref)
#    1182
#    1183         return _ref
#
# /usr/local/lib/python3.12/dist-packages/torch/_decomp/__init__.py in decomposition_decorator(fn)
#     223
#     224         # To handle allowing multiple aten_ops at once
# --> 225         pytree.tree_map_(register, aten_op)
#     226         return orig_fn
#     227
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_pytree.py in tree_map_(func, tree, is_leaf, *rests)
#    1570     leaves, treespec = tree_flatten(tree, is_leaf=is_leaf)
#    1571     flat_args = [leaves] + [treespec.flatten_up_to(r) for r in rests]
# -> 1572     deque(map(func, *flat_args), maxlen=0)  # consume and exhaust the iterable
#    1573     return tree
#    1574
#
# /usr/local/lib/python3.12/dist-packages/torch/_decomp/__init__.py in register(op)
#     220
#     221         def register(op):
# --> 222             _add_op_to_registry(registry, op, fn)
#     223
#     224         # To handle allowing multiple aten_ops at once
#
# /usr/local/lib/python3.12/dist-packages/torch/_decomp/__init__.py in _add_op_to_registry(registry, op, fn)
#      80             raise AssertionError(f"expected OpOverloadPacket, got {type(op)}")
#      81         for ol in op.overloads():
# ---> 82             overloads.append(getattr(op, ol))
#      83
#      84     for op_overload in overloads:
#
# KeyboardInterrupt:

# %% [markdown]
# ## 2. Format Standardization
# Microscopy images and CVAT annotations often come in mixed formats. In this section, we standardize our data:
# 1. Converting standard images (PNG/JPG) to TIFF formats.
# 2. Fixing bit-depth issues (e.g., converting unsupported `int8` TIFFs to standard `uint8`).
# 3. Ensuring images have the expected 3 channels (RGB) required by some processes.

# %%
# change the order of channels

im = Image.open('your-image-path')
img = im.convert("RGB")
im.save("your-save-path.tif", 'TIFF')

# %%
# convert to "normal" tiff: int8 -> uint8

input_path = 'your-input-path.tif'
output_path = 'your-output-path.tif'

image_data_int8 = tiff.imread(input_path)
image_data_uint8 = image_data_int8.astype(np.uint8)
tiff.imwrite(output_path, image_data_uint8)

with Image.open(output_path) as im:
    print("Success! The new file can now be opened by Pillow.")
    print(f"   -> Image Mode: {im.mode}, Size: {im.size}")

# %%
# the input image must have 3 channels

# convert to grayscale
image = Image.open("/content/img_212.TIF").convert("L")
image_array = np.array(image)

# duplicate and stack the 2D matrix to get H x W x 3
rgb_array = np.stack([image_array] * 3, axis = -1)

rgb_image = Image.fromarray(rgb_array, mode="RGB")
rgb_image.save("/content/example.tif")

# %% [markdown]
# ## 3. Image Resizing and Enhancement
# InstanSeg processes images efficiently at specific resolutions. Here, we check the native dimensions of our cryobiology samples and downscale them (* e.g., towards 512x512) to fit memory and model requirements. We also test contrast enhancement to make cellular structures more visible.
#
# \* All parameters are usually tuned manually, and the optimal ones are identified empirically.

# %%
# print size

image = Image.open("your-image-path.tif")
width, height = image.size
print(f"{width}x{height}")

# %%
# changing size

image = Image.open("your-image-path.tif")

# experiment with different parameters
w, h = image.width, image.height
scale = max(1, w // 512, h // 512)
new_size = (image.width // scale, image.height // scale)

# you may try both options below - and choose the best
# image_resized = image.resize(new_size, Image.LANCZOS)
image_resized = image.resize(new_size, Image.NEAREST)

image_resized.save("your-save-path.tif")

# %%
# contrast

image = Image.open("your-image-path.jpg")
enhancer = ImageEnhance.Contrast(image)
image_contrasted = enhancer.enhance(2)
image_contrasted.save("your-save-path.jpg")

# %%
# changing color - not needed in most cases
# add red color

image = Image.open("your-image-path.jpg").convert("RGB")
red_layer = Image.new("RGB", image.size, (255, 0, 0))
red_image = Image.blend(image, red_layer, alpha=0.5)
red_image.save("your-save-path.jpg")

# %% [markdown]
# ## 4. InstanSeg Model Evaluation
# With the data preprocessed, we pass our samples through the InstanSeg models. We evaluate both the fluorescence and brightfield modalities, extracting the number of detected cells and visualizing the predicted segmentation masks.

# %%
# Fluorescence pretrained model
# unexpectedly shows better results (in brightfield images)

image_array, pixel_size = instanseg_fluorescence.read_image("your-image-path.tif")
print(pixel_size)
print(image_array.shape)

labeled_output, image_tensor  = instanseg_fluorescence.eval_small_image(image_array, pixel_size,
                                                                               return_image_tensor = True)

# Cell calculation - custom function - implemented in fork repository
# !pip install git+https://github.com/sonyalytv/instanseg_cryobiology.git
# labeled_output, image_tensor, cells  = instanseg_fluorescence.eval_small_image(image_array, pixel_size,
#                                                                                return_image_tensor = True)
# print("Number of cells detected: ", cells)

print(labeled_output.shape)
print(labeled_output.dtype)
display = instanseg_fluorescence.display(image_tensor, labeled_output)

show_images(display, colorbar=False)

# %%
# Brightfield pretrained model
# Works better for nuclei segmentation

image_array, pixel_size = instanseg_brightfield.read_image("your-image-path.tif")

print(pixel_size)
print(image_array.shape)

labeled_output, image_tensor = instanseg_brightfield.eval_small_image(image_array,
                                                                      pixel_size,
                                                                      resolve_cell_and_nucleus=True,
                                                                      cleanup_fragments = True,
                                                                      target = "cells",
                                                                     verbosity = 0)

display = instanseg_brightfield.display(image_array, labeled_output)

show_images(display, colorbar=False)

# %% [markdown]
# ## 5. Verification and Diagnostics
# Finally, we provide utility blocks to inspect specific output files and verify the integrity of the segmentation masks.

# %%
# take a look at the mask or image - for visual inspection
img = io.imread("your-mask-path.png")
plt.imshow(img)
img.shape

# %%
# check mask values
img = cv2.imread("your-mask-path.tif", cv2.IMREAD_UNCHANGED)

print(f"Unique values found: {np.unique(img)}")
